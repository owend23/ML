# %% [markdown]
# <a href="https://colab.research.google.com/github/owend23/ML/blob/main/classification_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
import pandas as pd

# %%
CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']

train_path = tf.keras.utils.get_file(
    "iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file(
    "iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")

train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)

train_y = train.pop('Species')
test_y = test.pop('Species')

def input_fn(features, labels, training=True, batch_size=256):
  # Convert the inputs to a DataSet
  dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))

  # Shuffle and repeat if you are in training mode
  if training:
    dataset = dataset.shuffle(1000).repeat()
  
  return dataset.batch(batch_size)

my_feature_columns = []
for key in train.keys():
  my_feature_columns.append(tf.feature_column.numeric_column(key=key))

classifier = tf.estimator.DNNClassifier(
    feature_columns=my_feature_columns,
    hidden_units=[30, 10],
    n_classes=3)

classifier.train(
    input_fn=lambda: input_fn(train, train_y, training=True),
    steps=5000)

eval_result = classifier.evaluate(
    input_fn=lambda: input_fn(test, test_y, training=False))

print("\nTest set accuracy: {accuracy:0.3f}\n".format(**eval_result))

def input_fn(features, batch_size=256):
  return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

features = ["SepalLength", "SepalWidth", "PetalLength", "PetalWidth"]
predict = {}

print("Please type numeric values as prompted.")
for feature in features:
  valid = True
  while valid:
    val = input(feature + ": ")
    if not val.isdigit(): valid = False
  
  predict[feature] = [float(val)]

predictions = classifier.predict(input_fn=lambda: input_fn(predict))
for pred_dict in predictions:
  class_id = pred_dict['class_ids'][0]
  probability = pred_dict['probabilities'][class_id]

  print('Prediction is "{}" ({:.1f}%)'.format(
      SPECIES[class_id], 100 * probability
  ))

expected = ["Setosa", "Versicolor", "Virginica"]
predict_x = {
    'SepalLength': [5.1, 5.9, 6.9],
    'SepalWidth': [3.3, 3.0, 3.1],
    'PetalLength': [1.7, 4.2, 5.4],
    'PetalWidth': [0.5, 1.5, 2.1],
}
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpfhn4a_yg
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpfhn4a_yg', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpfhn4a_yg/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.0076573, step = 0
# INFO:tensorflow:global_step/sec: 430.838
# INFO:tensorflow:loss = 0.7919071, step = 100 (0.234 sec)
# INFO:tensorflow:global_step/sec: 508.363
# INFO:tensorflow:loss = 0.7294939, step = 200 (0.197 sec)
# INFO:tensorflow:global_step/sec: 539.266
# INFO:tensorflow:loss = 0.6877754, step = 300 (0.188 sec)
# INFO:tensorflow:global_step/sec: 543.082
# INFO:tensorflow:loss = 0.66787505, step = 400 (0.184 sec)
# INFO:tensorflow:global_step/sec: 539.751
# INFO:tensorflow:loss = 0.6426334, step = 500 (0.185 sec)
# INFO:tensorflow:global_step/sec: 540.642
# INFO:tensorflow:loss = 0.61465126, step = 600 (0.185 sec)
# INFO:tensorflow:global_step/sec: 525.62
# INFO:tensorflow:loss = 0.5967311, step = 700 (0.192 sec)
# INFO:tensorflow:global_step/sec: 539.338
# INFO:tensorflow:loss = 0.5834373, step = 800 (0.185 sec)
# INFO:tensorflow:global_step/sec: 551.894
# INFO:tensorflow:loss = 0.5659025, step = 900 (0.177 sec)
# INFO:tensorflow:global_step/sec: 513.232
# INFO:tensorflow:loss = 0.5695376, step = 1000 (0.198 sec)
# INFO:tensorflow:global_step/sec: 536.16
# INFO:tensorflow:loss = 0.5394248, step = 1100 (0.186 sec)
# INFO:tensorflow:global_step/sec: 489.301
# INFO:tensorflow:loss = 0.53888965, step = 1200 (0.202 sec)
# INFO:tensorflow:global_step/sec: 525.805
# INFO:tensorflow:loss = 0.523716, step = 1300 (0.190 sec)
# INFO:tensorflow:global_step/sec: 517.371
# INFO:tensorflow:loss = 0.5237534, step = 1400 (0.196 sec)
# INFO:tensorflow:global_step/sec: 552.331
# INFO:tensorflow:loss = 0.51881385, step = 1500 (0.179 sec)
# INFO:tensorflow:global_step/sec: 537.505
# INFO:tensorflow:loss = 0.5179243, step = 1600 (0.189 sec)
# INFO:tensorflow:global_step/sec: 495.354
# INFO:tensorflow:loss = 0.50168353, step = 1700 (0.201 sec)
# INFO:tensorflow:global_step/sec: 509.205
# INFO:tensorflow:loss = 0.49779356, step = 1800 (0.198 sec)
# INFO:tensorflow:global_step/sec: 531.65
# INFO:tensorflow:loss = 0.4894762, step = 1900 (0.183 sec)
# INFO:tensorflow:global_step/sec: 537.041
# INFO:tensorflow:loss = 0.5047002, step = 2000 (0.189 sec)
# INFO:tensorflow:global_step/sec: 528.667
# INFO:tensorflow:loss = 0.48229313, step = 2100 (0.187 sec)
# INFO:tensorflow:global_step/sec: 525.774
# INFO:tensorflow:loss = 0.48002177, step = 2200 (0.192 sec)
# INFO:tensorflow:global_step/sec: 494.16
# INFO:tensorflow:loss = 0.45906258, step = 2300 (0.203 sec)
# INFO:tensorflow:global_step/sec: 492.841
# INFO:tensorflow:loss = 0.4609691, step = 2400 (0.205 sec)
# INFO:tensorflow:global_step/sec: 529.443
# INFO:tensorflow:loss = 0.4422547, step = 2500 (0.194 sec)
# INFO:tensorflow:global_step/sec: 481.463
# INFO:tensorflow:loss = 0.43844178, step = 2600 (0.197 sec)
# INFO:tensorflow:global_step/sec: 511.446
# INFO:tensorflow:loss = 0.45371062, step = 2700 (0.196 sec)
# INFO:tensorflow:global_step/sec: 497.426
# INFO:tensorflow:loss = 0.4324109, step = 2800 (0.204 sec)
# INFO:tensorflow:global_step/sec: 513.72
# INFO:tensorflow:loss = 0.43628275, step = 2900 (0.195 sec)
# INFO:tensorflow:global_step/sec: 506.686
# INFO:tensorflow:loss = 0.43407464, step = 3000 (0.197 sec)
# INFO:tensorflow:global_step/sec: 480.641
# INFO:tensorflow:loss = 0.41706526, step = 3100 (0.207 sec)
# INFO:tensorflow:global_step/sec: 524.455
# INFO:tensorflow:loss = 0.43812206, step = 3200 (0.191 sec)
# INFO:tensorflow:global_step/sec: 471.307
# INFO:tensorflow:loss = 0.421023, step = 3300 (0.213 sec)
# INFO:tensorflow:global_step/sec: 499.406
# INFO:tensorflow:loss = 0.42607012, step = 3400 (0.200 sec)
# INFO:tensorflow:global_step/sec: 502.056
# INFO:tensorflow:loss = 0.4000671, step = 3500 (0.201 sec)
# INFO:tensorflow:global_step/sec: 525.524
# INFO:tensorflow:loss = 0.41067082, step = 3600 (0.188 sec)
# INFO:tensorflow:global_step/sec: 550.739
# INFO:tensorflow:loss = 0.41386324, step = 3700 (0.181 sec)
# INFO:tensorflow:global_step/sec: 497.703
# INFO:tensorflow:loss = 0.4110422, step = 3800 (0.201 sec)
# INFO:tensorflow:global_step/sec: 514.204
# INFO:tensorflow:loss = 0.40182656, step = 3900 (0.195 sec)
# INFO:tensorflow:global_step/sec: 537.443
# INFO:tensorflow:loss = 0.39815873, step = 4000 (0.186 sec)
# INFO:tensorflow:global_step/sec: 534.811
# INFO:tensorflow:loss = 0.39499795, step = 4100 (0.187 sec)
# INFO:tensorflow:global_step/sec: 468.222
# INFO:tensorflow:loss = 0.39739048, step = 4200 (0.213 sec)
# INFO:tensorflow:global_step/sec: 527.111
# INFO:tensorflow:loss = 0.38503778, step = 4300 (0.190 sec)
# INFO:tensorflow:global_step/sec: 556.213
# INFO:tensorflow:loss = 0.3747078, step = 4400 (0.177 sec)
# INFO:tensorflow:global_step/sec: 537.09
# INFO:tensorflow:loss = 0.38540864, step = 4500 (0.187 sec)
# INFO:tensorflow:global_step/sec: 551.471
# INFO:tensorflow:loss = 0.37933487, step = 4600 (0.182 sec)
# INFO:tensorflow:global_step/sec: 538.013
# INFO:tensorflow:loss = 0.36967897, step = 4700 (0.188 sec)
# INFO:tensorflow:global_step/sec: 510.823
# INFO:tensorflow:loss = 0.3770852, step = 4800 (0.195 sec)
# INFO:tensorflow:global_step/sec: 499.971
# INFO:tensorflow:loss = 0.37962532, step = 4900 (0.202 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmpfhn4a_yg/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 0.37115237.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-07-08T03:10:57
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpfhn4a_yg/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.21875s
# INFO:tensorflow:Finished evaluation at 2021-07-08-03:10:58
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.9, average_loss = 0.44266608, global_step = 5000, loss = 0.44266608
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: /tmp/tmpfhn4a_yg/model.ckpt-5000
#
# Test set accuracy: 0.900
#
# Please type numeric values as prompted.
# SepalLength: 6.9
# SepalWidth: 3.1
# PetalLength: 5.4
# PetalWidth: 2.1
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpfhn4a_yg/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Virginica" (60.9%)
